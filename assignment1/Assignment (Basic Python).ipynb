# %% [markdown]
# # Python Practice Problems

# %% [markdown]
# ### 1. Find the Largest of Two Numbers
# **Task:** Given two numbers, find the larger one.
# **Demo Input:**  5 and 6 <br>
# **Output:** 6

# %%
x= int(input('plz give your first number'))
y= int(input('plz give your second number'))
if x<y:
    print('the large number is ', y)
elif y<x:
    print('the large number is', x)
else:
    print('both number are equal')
# Out:
# plz give your first number 7
# plz give your second number 9
# the large number is  9

# %% [markdown]
# ### 2. Print Numbers from 1 to N
# **Task**: Given a number `n`, print all numbers from 1 to `n`. <br>
# **Demo Input**: `5`  <br>
# **Demo Output**:  1 2 3 4 5

# %%
n=int(input('plz give your number'))
for i in range(1,n+1,1):
      print(i)
# Out:
# plz give your number 5
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### 3. Check if a Number is Positive or Negative
# **Task**: Determine if the input number is positive, negative, or zero.
# **Demo Input**: `-3`
# **Demo Output**: `The number is Negative`

# %%
user_data=float(input('enter your number'))
if user_data<=-1:
    print('the number is negative')
elif user_data>=1:
    print('the number is positive')
else:
    print('the number is zero')
# Out:
# enter your number -3
# the number is negative

# %% [markdown]
# ### 4. Calculate the Sum of Digits
# **Task**: Given a number, find the sum of its digits.
# **Demo Input**: `123`
# **Demo Output**: `6`
# (Explanation: `1+2+3=6`)

# %%
list=[1,2,3]
total= 0
for x in list:
    total= total+x
print(total)
# Out:
# 6

# %% [markdown]
# ### 5. Find Factorial of a Number
# **Task**: Calculate the factorial of a given number.
# **Demo Input**: `4`
# **Demo Output**: `24`
# (Explanation: `4! = 4*3*2*1 = 24`)

# %%
x=4
total=0
for i in range(0,x,1):
    m1= i*x
    total = total+m1
print(total)
# Out:
# 24

# %% [markdown]
# ### 6. Count Occurrences of a Digit
# **Task**: Count how many times a specific digit appears max in a number.
# **Demo Input**:  1233321 <br>
# **Demo Output**: `3`  <br>
# (Explanation: `3` appears 3 times in `1233321`)

# %%
n=str(1233321)
count=0
for x in n:
    if x == '3':
        count=count+1

print(count)
# Out:
# 3

# %% [markdown]
# ### 7. Find the GCD of Two Numbers
# **Task**: Find the greatest common divisor (GCD) of two numbers.
# **Demo Input**: 8 and 12 <br>
# **Demo Output**: `4`

# %%
a= 12
b= 8
while b>0:
    r = a%b
    a=b
    b=r
print(a)
# Out:
# 4

# %% [markdown]
# ### 8. Reverse a String
# **Task**: Reverse the given string.
# **Demo Input**: `"aiquest"`
# **Demo Output**: `"tseuqia"`

# %%
data='aiquest'
for x in range(len(data)-1,-1,-1):
    print(data[x], end='')
# Out:
# tseuqia

# %% [markdown]
# ### 9. Check Armstrong Number
# **Task**: Check if a number is an Armstrong number (the sum of its digits raised to the power of the number of digits equals the number).
# **Demo Input**: `153`
# **Demo Output**: `153 is an Armstrong Number`
# (Explanation: \(1^3 + 5^3 + 3^3 = 153\))

# %%
n=153
c=0
for x in str(n):
    c=c+int(x)**len(str(n))
if c== n:
    print('{} is an Armstrong Number'.format(c))
else:
    print('{} is not an Armstrong Number'.format(n))
# Out:
# 153 is an Armstrong Number

# %% [markdown]
# ### 10. Generate a Pattern
# **Task**: Print a pyramid pattern with `n` rows.
# **Demo input:** 4 <br>
# **Output:** You will see the pyramid pattern with 4 rows

# %%
n=4
for x in range(1,n+1):
    print(' '*(n-x),end='')
    print('{} '.format(n)*x)
# Out:
#    4
#   4 4
#  4 4 4
# 4 4 4 4

# %% [markdown]
# # Good Luck!
